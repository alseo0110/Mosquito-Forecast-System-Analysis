# %% [markdown]
# <a href="https://colab.research.google.com/github/alseo0110/Mosquito-Forecast-System-Analysis/blob/main/data_cleansing2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# csv 파일 읽기

# %%
import pandas as pd

df = pd.read_csv('/content/강수량.csv', encoding='EUC-KR')

# df.head()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 757 entries, 0 to 756
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   	지점번호         757 non-null    int64
#  1   지점명           757 non-null    object
#  2   일시            757 non-null    object
#  3   강수량(mm)       365 non-null    float64
#  4   1시간최다강수량(mm)  366 non-null    float64
#  5   1시간최다강수량시각    253 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 35.6+ KB

# %% [markdown]
# 결측치 찾기

# %%
df.isna().sum()
df[df.isnull().any(axis=1)]
# Out:
#      \t지점번호 지점명          일시  강수량(mm)  1시간최다강수량(mm) 1시간최다강수량시각
# 2       108  서울  2021-05-03      NaN           NaN        NaN
# 5       108  서울  2021-05-06      NaN           NaN        NaN
# 7       108  서울  2021-05-08      NaN           NaN        NaN
# 8       108  서울  2021-05-09      NaN           NaN        NaN
# 9       108  서울  2021-05-10      0.0           0.0        NaN
# ..      ...  ..         ...      ...           ...        ...
# 747     108  서울  2025-05-12      NaN           NaN        NaN
# 748     108  서울  2025-05-13      NaN           NaN        NaN
# 749     108  서울  2025-05-14      NaN           0.0        NaN
# 753     108  서울  2025-05-18      NaN           NaN        NaN
# 756     108  서울  2025-05-21      NaN           NaN        NaN
#
# [504 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# \t지점번호            0
# 지점명               0
# 일시                0
# 강수량(mm)         392
# 1시간최다강수량(mm)    391
# 1시간최다강수량시각      504
# dtype: int64

# %% [markdown]
# 결측치 채우고 필요없는 컬럼 삭제하기

# %%
df = df.fillna(0)

df = df.drop(columns=['\t지점번호', '지점명', '1시간최다강수량(mm)', '1시간최다강수량시각'])

# %%
df.head()
# Out:
#            일시  강수량(mm)
# 0  2021-05-01      8.0
# 1  2021-05-02      1.7
# 2  2021-05-03      0.0
# 3  2021-05-04     19.6
# 4  2021-05-05      0.1

# %%
df.to_csv('/content/강수량_수정.csv', index = False, encoding="EUC-KR")
